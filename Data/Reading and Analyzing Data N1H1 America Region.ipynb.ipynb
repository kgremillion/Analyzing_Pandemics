# %%
#Imported libraries to read and analysis data 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Reading the data base from WHO.org regarding the H1N1 Epidemia

influenza_data= pd.read_csv('Influenza Raw Data 2008-2010 Americas Region .csv')

influenza_data
# Out:
#         Country Americas                      WHOREGION  \
# 0     Argentina       SA  Region of the Americas of WHO
# 1     Argentina       SA  Region of the Americas of WHO
# 2     Argentina       SA  Region of the Americas of WHO
# 3     Argentina       SA  Region of the Americas of WHO
# 4     Argentina       SA  Region of the Americas of WHO
# ...         ...      ...                            ...
# 2350    Uruguay       SA  Region of the Americas of WHO
# 2351    Uruguay       SA  Region of the Americas of WHO
# 2352    Uruguay       SA  Region of the Americas of WHO
# 2353    Uruguay       SA  Region of the Americas of WHO
# 2354    Uruguay       SA  Region of the Americas of WHO
#
#                     FLUREGION  Year  Week      Weather  \
# 0     Temperate South America  2008     1  Hot Weather
# 1     Temperate South America  2008     2  Hot Weather
# 2     Temperate South America  2008     3  Hot Weather
# 3     Temperate South America  2008     4  Hot Weather
# ...

# %%
#insert a column to sum the two type of influenza analyzed 
influenza_data['Sum_Influenza_Cases'] = influenza_data['AH1']+influenza_data['AH1N12009']

influenza_data.head(50)

# df['Discounted_Price'] = df['Cost'] - (0.1 * df['Cost'])
# Out:
#       Country Americas                      WHOREGION  \
# 0   Argentina       SA  Region of the Americas of WHO
# 1   Argentina       SA  Region of the Americas of WHO
# 2   Argentina       SA  Region of the Americas of WHO
# 3   Argentina       SA  Region of the Americas of WHO
# 4   Argentina       SA  Region of the Americas of WHO
# 5   Argentina       SA  Region of the Americas of WHO
# 6   Argentina       SA  Region of the Americas of WHO
# 7   Argentina       SA  Region of the Americas of WHO
# 8   Argentina       SA  Region of the Americas of WHO
# 9   Argentina       SA  Region of the Americas of WHO
# 10  Argentina       SA  Region of the Americas of WHO
# 11  Argentina       SA  Region of the Americas of WHO
# 12  Argentina       SA  Region of the Americas of WHO
# 13  Argentina       SA  Region of the Americas of WHO
# 14  Argentina       SA  Region of the Americas of WHO
# 15  Argentina       SA  Region of the Americas of WHO
# ...

# %%
my_plot = sales_totals.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weeks'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-3aa3e0294fd1> in <module>
# ----> 1 influenza_data['Weeks']
# ...

# %%
#Renaming the columns for easy IDF

rename_influenza = influenza_data.rename(columns = {'SDATE':'START_DATE', 'EDATE':'END_DATE','SPEC_RECEIVED_NB': 'NB_SPEC_RECEIVED','SPEC_PROCESSED_NB': 'NB_SPEC_PROCESSED','AH1': 'TYPEA H1','AH1N12009':'TYPE A H1N1','ALL_INF':'TOTAL POS INFLUENZA','ALL_INF2':'TOTAL NEG INFLUENZA','TITLE':'TYPE OF ACTIVITY'})
rename_influenza
# Out:
#         Country                      WHOREGION                FLUREGION  Year  \
# 0     Argentina  Region of the Americas of WHO  Temperate South America  2008
# 1     Argentina  Region of the Americas of WHO  Temperate South America  2008
# 2     Argentina  Region of the Americas of WHO  Temperate South America  2008
# 3     Argentina  Region of the Americas of WHO  Temperate South America  2008
# 4     Argentina  Region of the Americas of WHO  Temperate South America  2008
# ...         ...                            ...                      ...   ...
# 2350    Uruguay  Region of the Americas of WHO  Temperate South America  2010
# 2351    Uruguay  Region of the Americas of WHO  Temperate South America  2010
# 2352    Uruguay  Region of the Americas of WHO  Temperate South America  2010
# 2353    Uruguay  Region of the Americas of WHO  Temperate South America  2010
# 2354    Uruguay  Region of the Americas of WHO  Temperate South America  2010
#
# ...

# %%
#Create Data frame
