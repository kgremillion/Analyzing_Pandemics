# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import csv

# Import API key
from api_keys import g_key

# %%
# load csv from WeatherPy to a DataFrame
csv_load = []

with open('NA_list.csv','r', encoding="utf-8-sig") as csvfile:    
    NA_list = pd.read_csv(csvfile)
        
NA_list
# Out:
#                City Country        Date  Humidity    Lat     Lng  Max Temp  \
# 0           Lacombe      CA  1584317403        60  52.47 -113.74      9.00
# 1             Creel      MX  1584317291        41  27.75 -107.63     60.71
# 2    Cabo San Lucas      MX  1584317408        60  22.89 -109.91     73.00
# 3        Eau Claire      US  1584317273        50  44.81  -91.50     39.20
# 4           Guaymas      MX  1584317413        50  27.93 -110.90     82.99
# ..              ...     ...         ...       ...    ...     ...       ...
# 575   New Baltimore      US  1584318802        40  42.68  -82.74     37.00
# 576      Boissevain      CA  1584318804       100  49.23 -100.06     26.01
# 577          Kenora      CA  1584318785        79  49.82  -94.43     26.60
# 578        Grenfell      AU  1584318809        54 -33.90  148.17     68.50
# 579       Hammonton      US  1584318811        52  39.64  -74.80     50.00
#
#      Wind Speed
# 0          3.36
# 1         11.43
# 2          5.82
# 3          3.36
# 4         11.41
# ..          ...
# 575        9.17
# 576        8.05
# 577        8.05
# 578       14.32
# 579        4.70
#
# [580 rows x 8 columns]

# %%
# configure gkey
gmaps.configure(api_key=g_key)

# %%
# create weighted heatmap based on coordinates & himidity
fig = gmaps.figure()
heatmap_layer = gmaps.heatmap_layer(
    NA_list[['Lat', 'Lng']], weights=NA_list['Humidity'],
    max_intensity=40, point_radius=4.0)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
