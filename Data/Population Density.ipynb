# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# Study data files
Influenza = 'Influenza Raw Data 2008-2010 Americas Region .csv'


# Read the data and the study results
influenza_data= pd.read_csv(Influenza)
influenza_data.head()
# Out:
#      Country Americas                      WHOREGION                FLUREGION  \
# 0  Argentina       SA  Region of the Americas of WHO  Temperate South America
# 1  Argentina       SA  Region of the Americas of WHO  Temperate South America
# 2  Argentina       SA  Region of the Americas of WHO  Temperate South America
# 3  Argentina       SA  Region of the Americas of WHO  Temperate South America
# 4  Argentina       SA  Region of the Americas of WHO  Temperate South America
#
#    Year  Week      Weather Classification of Population       SDATE  \
# 0  2008     1  Hot Weather                          Low  12/31/2007
# 1  2008     2  Hot Weather                          Low    1/7/2008
# 2  2008     3  Hot Weather                          Low   1/14/2008
# 3  2008     4  Hot Weather                          Low   1/21/2008
# 4  2008     5  Hot Weather                          Low   1/28/2008
#
#        EDATE  SPEC_RECEIVED_NB  SPEC_PROCESSED_NB  AH1  AH1N12009  ALL_INF  \
# 0   1/6/2008               NaN               19.0  0.0        NaN      0.0
# 1  1/13/2008               NaN               21.0  0.0        NaN      0.0
# 2  1/20/2008               NaN               27.0  0.0        NaN      0.0
# 3  1/27/2008               NaN               25.0  0.0        NaN      0.0
# 4   2/3/2008               NaN               26.0  0.0        NaN      0.0
#
#    ALL_INF2        TITLE
# 0      19.0  No Activity
# 1      21.0  No Activity
# 2      27.0  No Activity
# 3      25.0  No Activity
# 4      26.0  No Activity

# %%
#Replace Nan values with 0 to make a better plot
influenza_data= influenza_data.fillna(0)
influenza_data
# Out:
#         Country Americas                      WHOREGION  \
# 0     Argentina       SA  Region of the Americas of WHO
# 1     Argentina       SA  Region of the Americas of WHO
# 2     Argentina       SA  Region of the Americas of WHO
# 3     Argentina       SA  Region of the Americas of WHO
# 4     Argentina       SA  Region of the Americas of WHO
# ...         ...      ...                            ...
# 2350    Uruguay       SA  Region of the Americas of WHO
# 2351    Uruguay       SA  Region of the Americas of WHO
# 2352    Uruguay       SA  Region of the Americas of WHO
# 2353    Uruguay       SA  Region of the Americas of WHO
# 2354    Uruguay       SA  Region of the Americas of WHO
#
#                     FLUREGION  Year  Week      Weather  \
# 0     Temperate South America  2008     1  Hot Weather
# 1     Temperate South America  2008     2  Hot Weather
# 2     Temperate South America  2008     3  Hot Weather
# 3     Temperate South America  2008     4  Hot Weather
# 4     Temperate South America  2008     5  Hot Weather
# ...                       ...   ...   ...          ...
# 2350  Temperate South America  2010    48  Hot Weather
# 2351  Temperate South America  2010    49  Hot Weather
# 2352  Temperate South America  2010    50  Hot Weather
# 2353  Temperate South America  2010    51  Hot Weather
# 2354  Temperate South America  2010    52  Hot Weather
#
#      Classification of Population       SDATE       EDATE  SPEC_RECEIVED_NB  \
# 0                             Low  12/31/2007    1/6/2008               0.0
# 1                             Low    1/7/2008   1/13/2008               0.0
# 2                             Low   1/14/2008   1/20/2008               0.0
# 3                             Low   1/21/2008   1/27/2008               0.0
# 4                             Low   1/28/2008    2/3/2008               0.0
# ...                           ...         ...         ...               ...
# 2350                          Low  11/29/2010   12/5/2010               0.0
# 2351                          Low   12/6/2010  12/12/2010               0.0
# 2352                          Low  12/13/2010  12/19/2010               0.0
# 2353                          Low  12/20/2010  12/26/2010               0.0
# 2354                          Low  12/27/2010    1/2/2011               0.0
#
#       SPEC_PROCESSED_NB  AH1  AH1N12009  ALL_INF  ALL_INF2        TITLE
# 0                  19.0  0.0        0.0      0.0      19.0  No Activity
# 1                  21.0  0.0        0.0      0.0      21.0  No Activity
# 2                  27.0  0.0        0.0      0.0      27.0  No Activity
# 3                  25.0  0.0        0.0      0.0      25.0  No Activity
# 4                  26.0  0.0        0.0      0.0      26.0  No Activity
# ...                 ...  ...        ...      ...       ...          ...
# 2350               34.0  0.0        0.0      4.0      30.0    No Report
# 2351               25.0  0.0        0.0      2.0      23.0    No Report
# 2352               15.0  0.0        0.0      1.0      14.0    No Report
# 2353               21.0  0.0        0.0      1.0      20.0    No Report
# 2354               21.0  0.0        0.0      2.0      19.0    No Report
#
# [2355 rows x 17 columns]

# %%
influenza_new= influenza_data[["Country", "Classification of Population", "ALL_INF2", "AH1N12009" ]]
groupby_influenza= influenza_new.groupby(["Country", "Classification of Population"])
# groupby_influenza= groupby_influenza.count()
groupby_influenza= groupby_influenza["ALL_INF2", "AH1N12009"].sum().reset_index()
groupby_influenza= groupby_influenza.sort_values(by= "ALL_INF2", ascending= False)
 #Create a new dictionary equivalent to the population density so as to sort data
custom_dict= {"High": 0, "Medium": 1, "Low":2}
groupby_influenza["Population Density Rank"]= groupby_influenza["Classification of Population"].map(custom_dict)
groupby_influenza= groupby_influenza.sort_values("Population Density Rank")
# groupby_influenza= groupby_influenza.set_index("Country")
groupby_influenza
# Out:
#                      Country Classification of Population  ALL_INF2  \
# 10                    Mexico                         High   91824.0
# 6                       Cuba                         High   13969.0
# 5                 Costa Rica                         High    9945.0
# 7                    Ecuador                         High    9030.0
# 9                   Honduras                         High    3233.0
# 3                      Chile                       Medium   70951.0
# 4                   Colombia                       Medium   20082.0
# 1                     Brazil                       Medium   15578.0
# 12                      Peru                       Medium   10139.0
# 13  United States of America                       Medium       0.0
# 0                  Argentina                          Low   94457.0
# 11                  Paraguay                          Low    5547.0
# 8                El Salvador                          Low    4361.0
# 14                   Uruguay                          Low    2786.0
# 2                     Canada                          Low       0.0
#
#     AH1N12009  Population Density Rank
# 10    72573.0                        0
# 6      1797.0                        0
# 5       757.0                        0
# 7      1732.0                        0
# 9       780.0                        0
# 3      4508.0                        1
# 4      2524.0                        1
# 1      2218.0                        1
# 12      611.0                        1
# 13   110332.0                        1
# 0      9549.0                        2
# 11      851.0                        2
# 8       793.0                        2
# 14      448.0                        2
# 2     39770.0                        2

# %%
#Drop Population Density Rank Column
groupby_influenza= groupby_influenza.drop('Population Density Rank', 1)
# Configure plot and ticks
population_pivot_index = groupby_influenza.set_index(['Country', 'Classification of Population'])
population_pivot_index.plot(kind = "bar", figsize=(20,10), legend=True)
plt.xlabel("Countries & Population Density")
plt.ylabel("Total Sum of Cases")
plt.title("Number of Cases in Relation to the Population Density")
#Save Graph
plt.savefig('Output/Number of Cases in Relation to the Population Density.png')
